# %%
# Object Detecion 
import cv2
from ultralytics import YOLO
#plots
import matplotlib.pyplot as plt
import seaborn as sns

#basics
import pandas as pd
import numpy as np
import os
import subprocess

from tqdm.notebook import tqdm

# Display image and videos
import IPython
from IPython.display import Video, display
# %matplotlib inline


import urllib.request 
import shutil

# %%
path = './行人提取的视频/qx242_231208_071059_071200.mp4'

# %%
#loading a YOLO model 
model = YOLO('yolov8x.pt')

#geting names from classes
dict_classes = model.model.names

# %%
# Auxiliary functions
def risize_frame(frame, scale_percent):
    """Function to resize an image in a percent scale"""
    width = int(frame.shape[1] * scale_percent / 100)
    height = int(frame.shape[0] * scale_percent / 100)
    dim = (width, height)

    # resize image
    resized = cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)
    return resized



def filter_tracks(centers, patience):
    """Function to filter track history"""
    filter_dict = {}
    for k, i in centers.items():
        d_frames = i.items()
        filter_dict[k] = dict(list(d_frames)[-patience:])

    return filter_dict


def update_tracking(centers_old,obj_center, thr_centers, lastKey, frame, frame_max):
    """Function to update track of objects"""
    is_new = 0
    lastpos = [(k, list(center.keys())[-1], list(center.values())[-1]) for k, center in centers_old.items()]
    lastpos = [(i[0], i[2]) for i in lastpos if abs(i[1] - frame) <= frame_max]
    # Calculating distance from existing centers points
    previous_pos = [(k,obj_center) for k,centers in lastpos if (np.linalg.norm(np.array(centers) - np.array(obj_center)) < thr_centers)]
    # if distance less than a threshold, it will update its positions
    if previous_pos:
        id_obj = previous_pos[0][0]
        centers_old[id_obj][frame] = obj_center
    
    # Else a new ID will be set to the given object
    else:
        if lastKey:
            last = lastKey.split('D')[1]
            id_obj = 'ID' + str(int(last)+1)
        else:
            id_obj = 'ID0'
            
        is_new = 1
        centers_old[id_obj] = {frame:obj_center}
        lastKey = list(centers_old.keys())[-1]

    
    return centers_old, id_obj, is_new, lastKey

# %%
### Configurations
#Verbose during prediction
verbose = False
# Scaling percentage of original frame
scale_percent = 100
# model confidence level
conf_level = 0.8
# Threshold of centers ( old\new)
thr_centers = 20
#Number of max frames to consider a object lost 
frame_max = 5
# Number of max tracked centers stored 
patience = 100
# ROI area color transparency
alpha = 0.1
#-------------------------------------------------------
# Reading video with cv2
video = cv2.VideoCapture(path)

# Objects to detect Yolo
class_IDS = [0] 
# Auxiliary variables
centers_old = {}

obj_id = 0 
end = []
frames_list = []
count_p = 0
lastKey = ''
print(f'[INFO] - Verbose during Prediction: {verbose}')


# Original informations of video
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = video.get(cv2.CAP_PROP_FPS)
print('[INFO] - Original Dim: ', (width, height))

# Scaling Video for better performance 
if scale_percent != 100:
    print('[INFO] - Scaling change may cause errors in pixels lines ')
    width = int(width * scale_percent / 100)
    height = int(height * scale_percent / 100)
    print('[INFO] - Dim Scaled: ', (width, height))
    

#-------------------------------------------------------
### Video output ####
video_name = 'result.mp4'
output_path = "rep_" + video_name
tmp_output_path = "tmp_" + output_path
VIDEO_CODEC = "MP4V"

output_video = cv2.VideoWriter(tmp_output_path, 
                               cv2.VideoWriter_fourcc(*VIDEO_CODEC), 
                               fps, (width, height))


#-------------------------------------------------------
# Executing Recognition 
for i in tqdm(range(int(video.get(cv2.CAP_PROP_FRAME_COUNT)))):
    
    # reading frame from video
    _, frame = video.read()
    
    #Applying resizing of read frame
    frame  = risize_frame(frame, scale_percent)
#     frame  = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    area_roi = [np.array([ (1250, 400),(750,400),(700,800) ,(1200,800)], np.int32)]
    ROI = frame[:, :]

  
    if verbose:
        print('Dimension Scaled(frame): ', (frame.shape[1], frame.shape[0]))

    # Getting predictions
    y_hat = model.predict(ROI, conf = conf_level, classes = class_IDS, device = 0, verbose = False)
    
    # Getting the bounding boxes, confidence and classes of the recognize objects in the current frame.
    boxes   = y_hat[0].boxes.xyxy.cpu().numpy()
    conf    = y_hat[0].boxes.conf.cpu().numpy()
    classes = y_hat[0].boxes.cls.cpu().numpy() 
    
    # Storing the above information in a dataframe
    positions_frame = pd.DataFrame(y_hat[0].cpu().numpy().boxes.data, columns = ['xmin', 'ymin', 'xmax', 'ymax', 'conf', 'class'])
    
    #Translating the numeric class labels to text
    labels = [dict_classes[i] for i in classes]
    
    
    # For each people, draw the bounding-box and counting each one the pass thought the ROI area
    for ix, row in enumerate(positions_frame.iterrows()):
        # Getting the coordinates of each vehicle (row)
        xmin, ymin, xmax, ymax, confidence, category,  = row[1].astype('int')

        # Calculating the center of the bounding-box
        center_x, center_y = int(((xmax+xmin))/2), int((ymax+ ymin)/2)
        
        #Updating the tracking for each object
        centers_old, id_obj, is_new, lastKey = update_tracking(centers_old, (center_x, center_y), thr_centers, lastKey, i, frame_max)
        

        #Updating people in roi
        count_p+=is_new
        
        # drawing center and bounding-box in the given frame 
        cv2.rectangle(ROI, (xmin, ymin), (xmax, ymax), (0,0,255), 2) # box
        for center_x,center_y in centers_old[id_obj].values():
            cv2.circle(ROI, (center_x,center_y), 5,(0,0,255),-1) # center of box
        
        # get the image of the object and output to notebook
        obj_img = frame[ymin:ymax, xmin:xmax]
        IPython.display.display(IPython.display.Image(data=cv2.imencode('.jpg', cv2.cvtColor(obj_img, cv2.COLOR_BGR2RGB))[1].tobytes()))


        #Drawing above the bounding-box the name of class recognized.
        cv2.putText(img=ROI, text=id_obj+':'+str(np.round(conf[ix],2)),
                    org= (xmin,ymin-10), fontFace=cv2.FONT_HERSHEY_TRIPLEX, fontScale=0.8, color=(0, 0, 255),thickness=1)
       
    
            
    #drawing the number of people
    cv2.putText(img=frame, text=f'Counts People in ROI: {count_p}', 
                org= (30,40), fontFace=cv2.FONT_HERSHEY_TRIPLEX, 
                fontScale=1.5, color=(255, 0, 0), thickness=1)
    
    # Filtering tracks history
    centers_old = filter_tracks(centers_old, patience)
    if verbose:
        print(contador_in, contador_out)
    
#     #Drawing the ROI area
#     overlay = frame.copy()
  
#     cv2.polylines(overlay, pts = area_roi, isClosed = True, color=(255, 0, 0),thickness=2)
#     cv2.fillPoly(overlay, area_roi, (255,0,0))
#     frame = cv2.addWeighted(overlay, alpha,frame , 1 - alpha, 0)

    #Saving frames in a list 
    frames_list.append(frame)
    #saving transformed frames in a output video formaat
    output_video.write(frame)
    
#Releasing the video    
output_video.release()


####  pos processing
# Fixing video output codec to run in the notebook\browser
if os.path.exists(output_path):
    os.remove(output_path)
    
subprocess.run(
    ["ffmpeg",  "-i", tmp_output_path,"-crf","18","-preset","veryfast","-hide_banner","-loglevel","error","-vcodec","libx264",output_path])
os.remove(tmp_output_path)
# Out:
# [INFO] - Verbose during Prediction: False
# [INFO] - Original Dim:  (1920, 1080)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
#   0%|          | 0/690 [00:00<?, ?it/s]

# %%
path = './行人提取的视频/qx242_231208_071059_071200.mp4'

### Configurations
# Scaling percentage of original frame
scale_percent = 100
#-------------------------------------------------------
# Reading video with cv2
video = cv2.VideoCapture(path)

# Objects to detect Yolo
class_IDS = [0] 
# Auxiliary variables
centers_old = {}



# Original informations of video
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = video.get(cv2.CAP_PROP_FPS)
print('[INFO] - Original Dim: ', (width, height))

# Scaling Video for better performance 
if scale_percent != 100:
    print('[INFO] - Scaling change may cause errors in pixels lines ')
    width = int(width * scale_percent / 100)
    height = int(height * scale_percent / 100)
    print('[INFO] - Dim Scaled: ', (width, height))
    

#-------------------------------------------------------
### Video output ####
video_name = 'track_result.mp4'
output_path = "rep_" + video_name
tmp_output_path = "tmp_" + output_path
VIDEO_CODEC = "MP4V"

output_video = cv2.VideoWriter(tmp_output_path, 
                               cv2.VideoWriter_fourcc(*VIDEO_CODEC), 
                               fps, (width, height))
#-------------------------------------------------------

#loading a YOLO model 
model = YOLO('yolov8x.pt')


results = model.track(path, classes=0, persist=True)
# Out:
# [INFO] - Original Dim:  (1920, 1080)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 10.3ms
# video 1/1 (frame 2/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.8ms
# video 1/1 (frame 3/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 4/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 5/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 6/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 7/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 8/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 9/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 10/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 11/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 12/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 13/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 14/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 15/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 16/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 17/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 18/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 19/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 20/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 21/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 22/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 23/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 24/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 25/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 26/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 27/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 28/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 29/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 30/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 31/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 32/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 33/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 34/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 35/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 36/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 37/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 38/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 39/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 40/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 41/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 42/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 43/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 44/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 45/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 46/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 47/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 48/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 49/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 50/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 51/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 52/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 53/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 54/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 55/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 56/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 57/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 58/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 59/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 60/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 61/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 62/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 63/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 64/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 65/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 66/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 67/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 68/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 69/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 70/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 71/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 72/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 73/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 74/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 75/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 76/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 77/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 78/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 79/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 80/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 81/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.8ms
# video 1/1 (frame 82/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 83/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 84/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 85/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 86/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 87/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 88/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 89/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 90/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 91/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 92/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 93/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 94/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 95/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 96/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 97/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 98/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 99/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 100/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 101/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 102/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 103/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 104/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 105/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 106/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 107/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 108/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 109/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 110/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 111/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 112/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 113/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 114/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 115/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 116/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 117/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 118/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 119/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 120/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 121/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 122/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 123/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 124/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 125/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 126/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 127/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 128/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 129/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 130/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 131/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 132/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 133/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 134/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 135/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 136/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 137/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 138/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 139/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 140/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 141/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 142/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 143/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 144/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 145/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 146/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 147/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 148/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 149/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 150/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 151/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 152/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 153/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 154/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 155/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 156/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 157/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 158/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 159/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 160/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 161/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 162/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 163/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 164/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 165/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 166/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 167/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.8ms
# video 1/1 (frame 168/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 169/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 170/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 171/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 172/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 173/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 174/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 175/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 176/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 177/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 178/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 179/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 180/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 181/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 182/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 183/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 184/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 185/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 186/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 187/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 188/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 189/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 190/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 191/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 192/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 193/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 194/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 195/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 196/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 197/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 198/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 199/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 200/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 201/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 202/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 203/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 204/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 205/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 206/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 207/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 208/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 209/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 210/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 211/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 212/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 14 persons, 9.9ms
# video 1/1 (frame 213/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 214/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 215/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 216/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 217/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 218/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 219/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 13 persons, 9.9ms
# video 1/1 (frame 220/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 221/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 222/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 223/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 224/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 225/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 12 persons, 9.9ms
# video 1/1 (frame 226/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 11 persons, 9.9ms
# video 1/1 (frame 227/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 228/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 229/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 230/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 231/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 232/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 233/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 234/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 235/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 236/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 237/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 238/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 10.8ms
# video 1/1 (frame 239/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 240/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 10 persons, 9.9ms
# video 1/1 (frame 241/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 242/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 243/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 244/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 245/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 246/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 247/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 248/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 249/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 9 persons, 9.9ms
# video 1/1 (frame 250/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 251/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 252/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 253/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 254/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 8 persons, 9.9ms
# video 1/1 (frame 255/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 256/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 257/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 258/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 259/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 260/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 261/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 262/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 263/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 264/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 265/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 266/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 267/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 268/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 269/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 270/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 271/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 272/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 273/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 274/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 275/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 276/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 277/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 278/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 279/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 280/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 281/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 282/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 283/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 284/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 285/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 286/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 287/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 288/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 289/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 290/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 291/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 292/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 293/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 294/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 295/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 296/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 297/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 298/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 299/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 300/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 301/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 302/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 303/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 304/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 305/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 306/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 307/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 308/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 309/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 310/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 311/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 312/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 313/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 314/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 315/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 316/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 317/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 318/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 319/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 320/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 321/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 322/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 323/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 324/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 325/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 326/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 327/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 328/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 329/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 330/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 331/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 332/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 333/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 334/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 335/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 336/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 337/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 338/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 339/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 340/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 341/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 342/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 343/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 344/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 345/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 346/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 347/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 348/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 349/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 350/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 351/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 352/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 353/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 354/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 355/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 356/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 357/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 358/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 359/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 360/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 361/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 362/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 363/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 364/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 365/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 366/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 367/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 368/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 369/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 4 persons, 9.9ms
# video 1/1 (frame 370/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 371/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 372/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 373/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 374/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 375/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 376/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 377/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 378/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 379/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 380/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 381/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 382/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 383/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 384/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 385/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 386/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 387/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 388/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 389/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 390/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 391/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 392/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 393/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 394/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 395/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 396/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 397/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 398/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 399/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# ...
# video 1/1 (frame 557/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 558/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 559/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 560/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 561/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 562/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 563/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 564/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 565/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 566/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 567/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 568/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 569/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 570/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 571/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 572/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 573/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 574/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 575/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 576/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 577/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 578/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 579/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 580/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 581/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 582/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 583/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 584/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 585/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 586/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 587/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 588/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 589/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 590/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 591/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 592/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 593/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 594/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 595/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 596/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 597/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 598/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 599/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 600/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 601/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 602/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 603/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 604/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 605/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 606/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 607/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 608/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 609/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 610/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 611/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 612/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 613/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 614/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 615/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 616/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 617/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 618/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 619/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 620/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 621/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 622/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 623/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 624/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 625/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 626/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 627/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 628/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 629/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 630/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 631/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 632/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 633/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 634/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 635/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 636/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 637/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 638/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 639/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 640/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 641/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 642/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 643/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 644/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 645/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 646/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 647/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 648/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 649/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 650/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 651/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 652/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 653/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 2 persons, 9.9ms
# video 1/1 (frame 654/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 655/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 656/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 657/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 658/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 659/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 660/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 661/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 662/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 663/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 664/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 665/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 666/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 667/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 668/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 669/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 670/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 671/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 672/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 673/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 674/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 675/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 676/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 677/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 678/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 679/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 680/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 681/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 682/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 683/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 684/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 685/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 686/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 687/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 688/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 689/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# video 1/1 (frame 690/690) /home/lab/cym/YOLO-ViT-PGC/行人提取的视频/qx242_231208_071059_071200.mp4: 384x640 3 persons, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
for r in results:
    frame = r.plot()
    # add number of people in the frame, left bottom corner, red color, white text, large font
    cur_cnt = r.boxes.id.shape[0]
    cv2.putText(frame, f'People: {cur_cnt}', (10, frame.shape[0]-10), cv2.FONT_HERSHEY_SIMPLEX, 6, (0, 0, 255), 10, 25)
    output_video.write(frame)
output_video.release()

# %%
####  pos processing
# Fixing video output codec to run in the notebook\browser
if os.path.exists(output_path):
    os.remove(output_path)
    
subprocess.run(
    ["ffmpeg",  "-i", tmp_output_path,"-crf","18","-preset","veryfast","-hide_banner","-loglevel","error","-vcodec","libx264",output_path])
os.remove(tmp_output_path)
